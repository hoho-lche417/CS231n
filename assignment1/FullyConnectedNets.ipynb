# %%
# This mounts your Google Drive to the Colab VM.
from google.colab import drive
drive.mount('/content/drive')

# TODO: Enter the foldername in your Drive where you have saved the unzipped
# assignment folder, e.g. 'cs231n/assignments/assignment1/'
FOLDERNAME = 'cs231n_2025/assignment1/'
assert FOLDERNAME is not None, "[!] Enter the foldername."

# Now that we've mounted your Drive, this ensures that
# the Python interpreter of the Colab VM can load
# python files from within it.
import sys
sys.path.append('/content/drive/My Drive/{}'.format(FOLDERNAME))

# This downloads the CIFAR-10 dataset to your Drive
# if it doesn't already exist.
# %cd /content/drive/My\ Drive/$FOLDERNAME/cs231n/datasets/
# %cd /content/drive/My\ Drive/$FOLDERNAME
# !bash get_datasets.sh
# %cd /content/drive/My\ Drive/$FOLDERNAME
# Out:
# Mounted at /content/drive
# /content/drive/My Drive/cs231n_2025/assignment1/cs231n/datasets
# /content/drive/My Drive/cs231n_2025/assignment1

# %% [markdown]
# # Multi-Layer Fully Connected Network
# In this exercise, you will implement a fully connected network with an arbitrary number of hidden layers.

# %%
# from google.colab import drive
# drive.mount('/content/drive')

# %% [markdown]
# Read through the `FullyConnectedNet` class in the file `cs231n/classifiers/fc_net.py`.
#
# Implement the network initialization, forward pass, and backward pass. Throughout this assignment, you will be implementing layers in `cs231n/layers.py`. You can re-use your implementations for `affine_forward`, `affine_backward`, `relu_forward`, `relu_backward`, and `softmax_loss` from before. For right now, don't worry about implementing dropout or batch/layer normalization yet, as you will add those features later.

# %%
# Setup cell.
import time
import numpy as np
import matplotlib.pyplot as plt
from cs231n.classifiers.fc_net import *
from cs231n.data_utils import get_CIFAR10_data
from cs231n.gradient_check import eval_numerical_gradient, eval_numerical_gradient_array
from cs231n.solver import Solver

# %matplotlib inline
plt.rcParams["figure.figsize"] = (10.0, 8.0)  # Set default size of plots.
plt.rcParams["image.interpolation"] = "nearest"
plt.rcParams["image.cmap"] = "gray"

# %load_ext autoreload
# %autoreload 2

def rel_error(x, y):
    """Returns relative error."""
    return np.max(np.abs(x - y) / (np.maximum(1e-8, np.abs(x) + np.abs(y))))

# %%
# Load the (preprocessed) CIFAR-10 data.
data = get_CIFAR10_data()
for k, v in list(data.items()):
    print(f"{k}: {v.shape}")
# Out:
# X_train: (49000, 3, 32, 32)
# y_train: (49000,)
# X_val: (1000, 3, 32, 32)
# y_val: (1000,)
# X_test: (1000, 3, 32, 32)
# y_test: (1000,)

# %% [markdown]
# ## Initial Loss and Gradient Check
#
# As a sanity check, run the following to check the initial loss and to gradient check the network both with and without regularization. This is a good way to see if the initial losses seem reasonable.
#
# For gradient checking, you should expect to see errors around 1e-7 or less.

# %%
list(range(10, 1, -1))
# Out:
# [10, 9, 8, 7, 6, 5, 4, 3, 2]

# %%
np.random.seed(231)
N, D, H1, H2, C = 2, 15, 20, 30, 10
X = np.random.randn(N, D)
y = np.random.randint(C, size=(N,))

for reg in [0, 3.14]:
    print("Running check with reg = ", reg)
    model = FullyConnectedNet(
        [H1, H2],
        input_dim=D,
        num_classes=C,
        reg=reg,
        weight_scale=5e-2,
        dtype=np.float64
    )

    loss, grads = model.loss(X, y)
    print("Initial loss: ", loss)

    # Most of the errors should be on the order of e-7 or smaller.
    # NOTE: It is fine however to see an error for W2 on the order of e-5
    # for the check when reg = 0.0
    for name in sorted(grads):
        f = lambda _: model.loss(X, y)[0]
        grad_num = eval_numerical_gradient(f, model.params[name], verbose=False, h=1e-5)
        print(f"{name} relative error: {rel_error(grad_num, grads[name])}")
# Out:
# Running check with reg =  0
# Initial loss:  3.3919674304905376
# W1 relative error: 5.6509765296703e-07
# W2 relative error: 2.9011562269627104e-07
# b1 relative error: 7.918599845170197e-08
# b2 relative error: 6.268302075569658e-10
# Running check with reg =  3.14
# Initial loss:  6.926468493472546
# W1 relative error: 4.818643392794582e-08
# W2 relative error: 3.171449019161023e-08
# b1 relative error: 4.813813766280619e-09
# b2 relative error: 7.367241733375882e-10

# %% [markdown]
# As another sanity check, make sure your network can overfit on a small dataset of 50 images. First, we will try a three-layer network with 100 units in each hidden layer. In the following cell, tweak the **learning rate** and **weight initialization scale** to overfit and achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a three-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  "X_train": data["X_train"][:num_train],
  "y_train": data["y_train"][:num_train],
  "X_val": data["X_val"],
  "y_val": data["y_val"],
}

weight_scale = 1e-2   # Experiment with this!
learning_rate = 5e-4  # Experiment with this!


model = FullyConnectedNet(
    [100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule="sgd",
    optim_config={"learning_rate": learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title("Training loss history")
plt.xlabel("Iteration")
plt.ylabel("Training loss")
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 5.881184
# (Epoch 0 / 20) train acc: 0.280000; val_acc: 0.071000
# (Epoch 1 / 20) train acc: 0.360000; val_acc: 0.084000
# (Epoch 2 / 20) train acc: 0.520000; val_acc: 0.133000
# (Epoch 3 / 20) train acc: 0.580000; val_acc: 0.151000
# (Epoch 4 / 20) train acc: 0.720000; val_acc: 0.156000
# (Epoch 5 / 20) train acc: 0.820000; val_acc: 0.149000
# (Iteration 11 / 40) loss: 0.384048
# (Epoch 6 / 20) train acc: 0.860000; val_acc: 0.149000
# (Epoch 7 / 20) train acc: 0.960000; val_acc: 0.144000
# (Epoch 8 / 20) train acc: 0.980000; val_acc: 0.145000
# (Epoch 9 / 20) train acc: 0.980000; val_acc: 0.149000
# (Epoch 10 / 20) train acc: 1.000000; val_acc: 0.149000
# (Iteration 21 / 40) loss: 0.096742
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.152000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.152000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.148000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.147000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.154000
# (Iteration 31 / 40) loss: 0.057763
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.152000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.153000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.151000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.151000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.155000

# %% [markdown]
# Now, try to use a five-layer network with 100 units on each layer to overfit on 50 training examples. Again, you will have to adjust the learning rate and weight initialization scale, but you should be able to achieve 100% training accuracy within 20 epochs.

# %%
# TODO: Use a five-layer Net to overfit 50 training examples by
# tweaking just the learning rate and initialization scale.

num_train = 50
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

weight_scale = 5e-2   # Experiment with this!
learning_rate = 1e-3  # Experiment with this!

model = FullyConnectedNet(
    [100, 100, 100, 100],
    weight_scale=weight_scale,
    dtype=np.float64
)
solver = Solver(
    model,
    small_data,
    print_every=10,
    num_epochs=20,
    batch_size=25,
    update_rule='sgd',
    optim_config={'learning_rate': learning_rate},
)
solver.train()

plt.plot(solver.loss_history)
plt.title('Training loss history')
plt.xlabel('Iteration')
plt.ylabel('Training loss')
plt.grid(linestyle='--', linewidth=0.5)
plt.show()
# Out:
# (Iteration 1 / 40) loss: 19.339497
# (Epoch 0 / 20) train acc: 0.020000; val_acc: 0.013000
# (Epoch 1 / 20) train acc: 0.100000; val_acc: 0.036000
# (Epoch 2 / 20) train acc: 0.420000; val_acc: 0.067000
# (Epoch 3 / 20) train acc: 0.580000; val_acc: 0.095000
# (Epoch 4 / 20) train acc: 0.740000; val_acc: 0.092000
# (Epoch 5 / 20) train acc: 0.820000; val_acc: 0.118000
# (Iteration 11 / 40) loss: 0.747135
# (Epoch 6 / 20) train acc: 0.880000; val_acc: 0.109000
# (Epoch 7 / 20) train acc: 0.920000; val_acc: 0.120000
# (Epoch 8 / 20) train acc: 0.960000; val_acc: 0.118000
# (Epoch 9 / 20) train acc: 0.980000; val_acc: 0.116000
# (Epoch 10 / 20) train acc: 0.980000; val_acc: 0.125000
# (Iteration 21 / 40) loss: 0.155250
# (Epoch 11 / 20) train acc: 1.000000; val_acc: 0.121000
# (Epoch 12 / 20) train acc: 1.000000; val_acc: 0.128000
# (Epoch 13 / 20) train acc: 1.000000; val_acc: 0.127000
# (Epoch 14 / 20) train acc: 1.000000; val_acc: 0.124000
# (Epoch 15 / 20) train acc: 1.000000; val_acc: 0.126000
# (Iteration 31 / 40) loss: 0.074125
# (Epoch 16 / 20) train acc: 1.000000; val_acc: 0.129000
# (Epoch 17 / 20) train acc: 1.000000; val_acc: 0.128000
# (Epoch 18 / 20) train acc: 1.000000; val_acc: 0.128000
# (Epoch 19 / 20) train acc: 1.000000; val_acc: 0.128000
# (Epoch 20 / 20) train acc: 1.000000; val_acc: 0.132000

# %% [markdown]
# ## Inline Question 1:
# Did you notice anything about the comparative difficulty of training the three-layer network vs. training the five-layer network? In particular, based on your experience, which network seemed more sensitive to the initialization scale? Why do you think that is the case?
#
# ## Answer:
# The primary reason is deep networks suffer from vanishing or exploding gradients due to the long distance of the chain rule. The secondary reason is the more complex shape introduced by deeper networks.

# %% [markdown]
# # Update rules
# So far we have used vanilla stochastic gradient descent (SGD) as our update rule. More sophisticated update rules can make it easier to train deep networks. We will implement a few of the most commonly used update rules and compare them to vanilla SGD.

# %% [markdown]
# ## SGD+Momentum
# Stochastic gradient descent with momentum is a widely used update rule that tends to make deep networks converge faster than vanilla stochastic gradient descent. See the Momentum Update section at http://cs231n.github.io/neural-networks-3/#sgd for more information.
#
# Open the file `cs231n/optim.py` and read the documentation at the top of the file to make sure you understand the API. Implement the SGD+momentum update rule in the function `sgd_momentum` and run the following to check your implementation. You should see errors less than e-8.

# %%
from cs231n.optim import sgd_momentum

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
v = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {"learning_rate": 1e-3, "velocity": v}
next_w, _ = sgd_momentum(w, dw, config=config)

expected_next_w = np.asarray([
  [ 0.1406,      0.20738947,  0.27417895,  0.34096842,  0.40775789],
  [ 0.47454737,  0.54133684,  0.60812632,  0.67491579,  0.74170526],
  [ 0.80849474,  0.87528421,  0.94207368,  1.00886316,  1.07565263],
  [ 1.14244211,  1.20923158,  1.27602105,  1.34281053,  1.4096    ]])
expected_velocity = np.asarray([
  [ 0.5406,      0.55475789,  0.56891579, 0.58307368,  0.59723158],
  [ 0.61138947,  0.62554737,  0.63970526,  0.65386316,  0.66802105],
  [ 0.68217895,  0.69633684,  0.71049474,  0.72465263,  0.73881053],
  [ 0.75296842,  0.76712632,  0.78128421,  0.79544211,  0.8096    ]])

# Should see relative errors around e-8 or less
print("next_w error: ", rel_error(next_w, expected_next_w))
print("velocity error: ", rel_error(expected_velocity, config["velocity"]))
# Out:
# next_w error:  8.882347033505819e-09
# velocity error:  4.269287743278663e-09

# %% [markdown]
# Once you have done so, run the following to train a six-layer network with both SGD and SGD+momentum. You should see the SGD+momentum update rule converge faster.

# %%
num_train = 4000
small_data = {
  'X_train': data['X_train'][:num_train],
  'y_train': data['y_train'][:num_train],
  'X_val': data['X_val'],
  'y_val': data['y_val'],
}

solvers = {}

for update_rule in ['sgd', 'sgd_momentum']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )

    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': 5e-3},
        verbose=True,
    )
    solvers[update_rule] = solver
    solver.train()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"loss_{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"train_acc_{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"val_acc_{update_rule}")

for ax in axes:
    ax.legend(loc="best", ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  sgd
# (Iteration 1 / 200) loss: 6.604179
# (Epoch 0 / 5) train acc: 0.110000; val_acc: 0.114000
# (Iteration 11 / 200) loss: 2.776593
# (Iteration 21 / 200) loss: 2.521438
# (Iteration 31 / 200) loss: 2.142262
# (Epoch 1 / 5) train acc: 0.217000; val_acc: 0.201000
# (Iteration 41 / 200) loss: 2.334217
# (Iteration 51 / 200) loss: 2.060478
# (Iteration 61 / 200) loss: 1.821878
# (Iteration 71 / 200) loss: 2.067628
# (Epoch 2 / 5) train acc: 0.296000; val_acc: 0.264000
# (Iteration 81 / 200) loss: 2.034414
# (Iteration 91 / 200) loss: 1.957585
# (Iteration 101 / 200) loss: 1.868761
# (Iteration 111 / 200) loss: 1.867639
# (Epoch 3 / 5) train acc: 0.344000; val_acc: 0.277000
# (Iteration 121 / 200) loss: 1.997006
# (Iteration 131 / 200) loss: 1.783600
# (Iteration 141 / 200) loss: 1.799556
# (Iteration 151 / 200) loss: 1.872193
# (Epoch 4 / 5) train acc: 0.408000; val_acc: 0.306000
# (Iteration 161 / 200) loss: 1.635033
# (Iteration 171 / 200) loss: 1.716162
# (Iteration 181 / 200) loss: 1.767101
# (Iteration 191 / 200) loss: 1.573604
# (Epoch 5 / 5) train acc: 0.332000; val_acc: 0.270000
# Running with  sgd_momentum
# (Iteration 1 / 200) loss: 8.499104
# (Epoch 0 / 5) train acc: 0.035000; val_acc: 0.023000
# (Iteration 11 / 200) loss: 2.429061
# (Iteration 21 / 200) loss: 2.097011
# (Iteration 31 / 200) loss: 1.942737
# (Epoch 1 / 5) train acc: 0.295000; val_acc: 0.231000
# (Iteration 41 / 200) loss: 2.123710
# (Iteration 51 / 200) loss: 1.815988
# (Iteration 61 / 200) loss: 1.845414
# (Iteration 71 / 200) loss: 1.775143
# (Epoch 2 / 5) train acc: 0.388000; val_acc: 0.306000
# (Iteration 81 / 200) loss: 1.771062
# (Iteration 91 / 200) loss: 1.641421
# (Iteration 101 / 200) loss: 1.465885
# (Iteration 111 / 200) loss: 1.459905
# (Epoch 3 / 5) train acc: 0.498000; val_acc: 0.375000
# (Iteration 121 / 200) loss: 1.377127
# (Iteration 131 / 200) loss: 1.721311
# (Iteration 141 / 200) loss: 1.484652
# (Iteration 151 / 200) loss: 1.380226
# (Epoch 4 / 5) train acc: 0.492000; val_acc: 0.346000
# (Iteration 161 / 200) loss: 1.404955
# (Iteration 171 / 200) loss: 1.203279
# (Iteration 181 / 200) loss: 1.428040
# (Iteration 191 / 200) loss: 1.471487
# (Epoch 5 / 5) train acc: 0.562000; val_acc: 0.380000

# %% [markdown]
# ## RMSProp and Adam
# RMSProp [1] and Adam [2] are update rules that set per-parameter learning rates by using a running average of the second moments of gradients.
#
# In the file `cs231n/optim.py`, implement the RMSProp update rule in the `rmsprop` function and implement the Adam update rule in the `adam` function, and check your implementations using the tests below.
#
# **NOTE:** Please implement the _complete_ Adam update rule (with the bias correction mechanism), not the first simplified version mentioned in the course notes.
#
# [1] Tijmen Tieleman and Geoffrey Hinton. "Lecture 6.5-rmsprop: Divide the gradient by a running average of its recent magnitude." COURSERA: Neural Networks for Machine Learning 4 (2012).
#
# [2] Diederik Kingma and Jimmy Ba, "Adam: A Method for Stochastic Optimization", ICLR 2015.

# %%
# Test RMSProp implementation
from cs231n.optim import rmsprop

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
cache = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'cache': cache}
next_w, _ = rmsprop(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.39223849, -0.34037513, -0.28849239, -0.23659121, -0.18467247],
  [-0.132737,   -0.08078555, -0.02881884,  0.02316247,  0.07515774],
  [ 0.12716641,  0.17918792,  0.23122175,  0.28326742,  0.33532447],
  [ 0.38739248,  0.43947102,  0.49155973,  0.54365823,  0.59576619]])
expected_cache = np.asarray([
  [ 0.5976,      0.6126277,   0.6277108,   0.64284931,  0.65804321],
  [ 0.67329252,  0.68859723,  0.70395734,  0.71937285,  0.73484377],
  [ 0.75037008,  0.7659518,   0.78158892,  0.79728144,  0.81302936],
  [ 0.82883269,  0.84469141,  0.86060554,  0.87657507,  0.8926    ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('cache error: ', rel_error(expected_cache, config['cache']))
# Out:
# next_w error:  9.524687511038133e-08
# cache error:  2.6477955807156126e-09

# %%
# Test Adam implementation
from cs231n.optim import adam

N, D = 4, 5
w = np.linspace(-0.4, 0.6, num=N*D).reshape(N, D)
dw = np.linspace(-0.6, 0.4, num=N*D).reshape(N, D)
m = np.linspace(0.6, 0.9, num=N*D).reshape(N, D)
v = np.linspace(0.7, 0.5, num=N*D).reshape(N, D)

config = {'learning_rate': 1e-2, 'm': m, 'v': v, 't': 5}
next_w, config = adam(w, dw, config=config)

expected_next_w = np.asarray([
  [-0.40094747, -0.34836187, -0.29577703, -0.24319299, -0.19060977],
  [-0.1380274,  -0.08544591, -0.03286534,  0.01971428,  0.0722929],
  [ 0.1248705,   0.17744702,  0.23002243,  0.28259667,  0.33516969],
  [ 0.38774145,  0.44031188,  0.49288093,  0.54544852,  0.59801459]])
expected_v = np.asarray([
  [ 0.69966,     0.68908382,  0.67851319,  0.66794809,  0.65738853,],
  [ 0.64683452,  0.63628604,  0.6257431,   0.61520571,  0.60467385,],
  [ 0.59414753,  0.58362676,  0.57311152,  0.56260183,  0.55209767,],
  [ 0.54159906,  0.53110598,  0.52061845,  0.51013645,  0.49966,   ]])
expected_m = np.asarray([
  [ 0.48,        0.49947368,  0.51894737,  0.53842105,  0.55789474],
  [ 0.57736842,  0.59684211,  0.61631579,  0.63578947,  0.65526316],
  [ 0.67473684,  0.69421053,  0.71368421,  0.73315789,  0.75263158],
  [ 0.77210526,  0.79157895,  0.81105263,  0.83052632,  0.85      ]])

# You should see relative errors around e-7 or less
print('next_w error: ', rel_error(expected_next_w, next_w))
print('v error: ', rel_error(expected_v, config['v']))
print('m error: ', rel_error(expected_m, config['m']))
# Out:
# next_w error:  1.1395691798535431e-07
# v error:  4.208314038113071e-09
# m error:  4.214963193114416e-09

# %% [markdown]
# Once you have debugged your RMSProp and Adam implementations, run the following to train a pair of deep networks using these new update rules:

# %%
learning_rates = {'rmsprop': 1e-4, 'adam': 1e-3}
for update_rule in ['adam', 'rmsprop']:
    print('Running with ', update_rule)
    model = FullyConnectedNet(
        [100, 100, 100, 100, 100],
        weight_scale=5e-2
    )
    solver = Solver(
        model,
        small_data,
        num_epochs=5,
        batch_size=100,
        update_rule=update_rule,
        optim_config={'learning_rate': learning_rates[update_rule]},
        verbose=True
    )
    solvers[update_rule] = solver
    solver.train()
    print()

fig, axes = plt.subplots(3, 1, figsize=(15, 15))

axes[0].set_title('Training loss')
axes[0].set_xlabel('Iteration')
axes[1].set_title('Training accuracy')
axes[1].set_xlabel('Epoch')
axes[2].set_title('Validation accuracy')
axes[2].set_xlabel('Epoch')

for update_rule, solver in solvers.items():
    axes[0].plot(solver.loss_history, label=f"{update_rule}")
    axes[1].plot(solver.train_acc_history, label=f"{update_rule}")
    axes[2].plot(solver.val_acc_history, label=f"{update_rule}")

for ax in axes:
    ax.legend(loc='best', ncol=4)
    ax.grid(linestyle='--', linewidth=0.5)

plt.show()
# Out:
# Running with  adam
# (Iteration 1 / 200) loss: 9.228033
# (Epoch 0 / 5) train acc: 0.063000; val_acc: 0.075000
# (Iteration 11 / 200) loss: 2.170895
# (Iteration 21 / 200) loss: 2.180413
# (Iteration 31 / 200) loss: 1.708963
# (Epoch 1 / 5) train acc: 0.373000; val_acc: 0.290000
# (Iteration 41 / 200) loss: 1.781709
# (Iteration 51 / 200) loss: 1.864649
# (Iteration 61 / 200) loss: 1.644190
# (Iteration 71 / 200) loss: 1.389279
# (Epoch 2 / 5) train acc: 0.467000; val_acc: 0.318000
# (Iteration 81 / 200) loss: 1.625452
# (Iteration 91 / 200) loss: 1.428549
# (Iteration 101 / 200) loss: 1.391291
# (Iteration 111 / 200) loss: 1.584349
# (Epoch 3 / 5) train acc: 0.525000; val_acc: 0.344000
# (Iteration 121 / 200) loss: 1.403453
# (Iteration 131 / 200) loss: 1.415208
# (Iteration 141 / 200) loss: 1.302797
# (Iteration 151 / 200) loss: 1.260879
# (Epoch 4 / 5) train acc: 0.553000; val_acc: 0.340000
# (Iteration 161 / 200) loss: 1.455446
# (Iteration 171 / 200) loss: 1.355603
# (Iteration 181 / 200) loss: 1.207360
# (Iteration 191 / 200) loss: 1.171107
# (Epoch 5 / 5) train acc: 0.586000; val_acc: 0.352000
#
# Running with  rmsprop
# (Iteration 1 / 200) loss: 10.867908
# (Epoch 0 / 5) train acc: 0.003000; val_acc: 0.002000
# (Iteration 11 / 200) loss: 2.925471
# (Iteration 21 / 200) loss: 2.191008
# (Iteration 31 / 200) loss: 2.225850
# (Epoch 1 / 5) train acc: 0.313000; val_acc: 0.268000
# (Iteration 41 / 200) loss: 2.036908
# (Iteration 51 / 200) loss: 1.765284
# (Iteration 61 / 200) loss: 1.902022
# (Iteration 71 / 200) loss: 1.728448
# (Epoch 2 / 5) train acc: 0.398000; val_acc: 0.310000
# (Iteration 81 / 200) loss: 1.680270
# (Iteration 91 / 200) loss: 1.686440
# (Iteration 101 / 200) loss: 1.647542
# (Iteration 111 / 200) loss: 1.671111
# (Epoch 3 / 5) train acc: 0.469000; val_acc: 0.328000
# (Iteration 121 / 200) loss: 1.506278
# (Iteration 131 / 200) loss: 1.576910
# (Iteration 141 / 200) loss: 1.434190
# (Iteration 151 / 200) loss: 1.425858
# (Epoch 4 / 5) train acc: 0.473000; val_acc: 0.333000
# (Iteration 161 / 200) loss: 1.560866
# (Iteration 171 / 200) loss: 1.435553
# (Iteration 181 / 200) loss: 1.354562
# (Iteration 191 / 200) loss: 1.465132
# (Epoch 5 / 5) train acc: 0.526000; val_acc: 0.326000

# %% [markdown]
# ## Inline Question 2:
#
# AdaGrad, like Adam, is a per-parameter optimization method that uses the following update rule:
#
# ```
# cache += dw**2
# w += - learning_rate * dw / (np.sqrt(cache) + eps)
# ```
#
# John notices that when he was training a network with AdaGrad that the updates became very small, and that his network was learning slowly. Using your knowledge of the AdaGrad update rule, why do you think the updates would become very small? Would Adam have the same issue?
#
#
# ## Answer:
# The value of cache accumulates over time, so the learning rate is effectively approaching to zero by dividing the cache. Adam solves this issue by computing a weighted average of the cache and the gradients without accumulating the magnitude of the cache value.

# %% [markdown]
# # Train a Good Model!
# Train the best fully connected model that you can on CIFAR-10, storing your best model in the `best_model` variable. We require you to get at least 50% accuracy on the validation set using a fully connected network.
#
# If you are careful it should be possible to get accuracies above 55%, but we don't require it for this part and won't assign extra credit for doing so. Later in the next assignment, we will ask you to train the best convolutional network that you can on CIFAR-10, and we would prefer that you spend your effort working on convolutional networks rather than fully connected networks.
#
# **Note:** In the next assignment, you will learn techniques like BatchNormalization and Dropout which can help you train powerful models.

# %%
best_model = None

################################################################################
# TODO: Train the best FullyConnectedNet that you can on CIFAR-10. You might   #
# find batch/layer normalization and dropout useful. Store your best model in  #
# the best_model variable.                                                     #
################################################################################
# *****START OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
lr = 3e-3
model = FullyConnectedNet(
    [100, 100, 100, 100, 100],
    weight_scale=5e-2
)
solver = Solver(
    model,
    data,
    num_epochs=20,
    batch_size=300,
    update_rule='adam',
    optim_config={'learning_rate': lr},
    verbose=True
)
solver.train()
# *****END OF YOUR CODE (DO NOT DELETE/MODIFY THIS LINE)*****
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
# Out:
# (Iteration 1 / 3260) loss: 6.220281
# (Epoch 0 / 20) train acc: 0.147000; val_acc: 0.139000
# (Iteration 11 / 3260) loss: 2.313614
# (Iteration 21 / 3260) loss: 2.094585
# (Iteration 31 / 3260) loss: 2.008027
# (Iteration 41 / 3260) loss: 1.917242
# (Iteration 51 / 3260) loss: 1.872857
# (Iteration 61 / 3260) loss: 1.809061
# (Iteration 71 / 3260) loss: 1.792411
# (Iteration 81 / 3260) loss: 1.792976
# (Iteration 91 / 3260) loss: 1.668134
# (Iteration 101 / 3260) loss: 1.735772
# (Iteration 111 / 3260) loss: 1.747576
# (Iteration 121 / 3260) loss: 1.623080
# (Iteration 131 / 3260) loss: 1.611215
# (Iteration 141 / 3260) loss: 1.614302
# (Iteration 151 / 3260) loss: 1.717042
# (Iteration 161 / 3260) loss: 1.752275
# (Epoch 1 / 20) train acc: 0.425000; val_acc: 0.439000
# (Iteration 171 / 3260) loss: 1.535273
# (Iteration 181 / 3260) loss: 1.670592
# (Iteration 191 / 3260) loss: 1.567594
# (Iteration 201 / 3260) loss: 1.597844
# (Iteration 211 / 3260) loss: 1.522595
# (Iteration 221 / 3260) loss: 1.540640
# (Iteration 231 / 3260) loss: 1.558285
# (Iteration 241 / 3260) loss: 1.501904
# (Iteration 251 / 3260) loss: 1.580557
# (Iteration 261 / 3260) loss: 1.582145
# (Iteration 271 / 3260) loss: 1.597978
# (Iteration 281 / 3260) loss: 1.541421
# (Iteration 291 / 3260) loss: 1.535302
# (Iteration 301 / 3260) loss: 1.570056
# (Iteration 311 / 3260) loss: 1.473136
# (Iteration 321 / 3260) loss: 1.557897
# (Epoch 2 / 20) train acc: 0.469000; val_acc: 0.451000
# (Iteration 331 / 3260) loss: 1.543238
# (Iteration 341 / 3260) loss: 1.537803
# (Iteration 351 / 3260) loss: 1.395980
# (Iteration 361 / 3260) loss: 1.397252
# (Iteration 371 / 3260) loss: 1.546832
# (Iteration 381 / 3260) loss: 1.610282
# (Iteration 391 / 3260) loss: 1.432404
# (Iteration 401 / 3260) loss: 1.360643
# (Iteration 411 / 3260) loss: 1.482578
# (Iteration 421 / 3260) loss: 1.599637
# (Iteration 431 / 3260) loss: 1.555054
# (Iteration 441 / 3260) loss: 1.365639
# (Iteration 451 / 3260) loss: 1.462538
# (Iteration 461 / 3260) loss: 1.366369
# (Iteration 471 / 3260) loss: 1.562153
# (Iteration 481 / 3260) loss: 1.375065
# (Epoch 3 / 20) train acc: 0.496000; val_acc: 0.475000
# (Iteration 491 / 3260) loss: 1.355166
# (Iteration 501 / 3260) loss: 1.506830
# (Iteration 511 / 3260) loss: 1.502967
# (Iteration 521 / 3260) loss: 1.590552
# (Iteration 531 / 3260) loss: 1.490746
# (Iteration 541 / 3260) loss: 1.383493
# (Iteration 551 / 3260) loss: 1.407017
# (Iteration 561 / 3260) loss: 1.418124
# (Iteration 571 / 3260) loss: 1.518762
# (Iteration 581 / 3260) loss: 1.335965
# (Iteration 591 / 3260) loss: 1.469668
# (Iteration 601 / 3260) loss: 1.362492
# (Iteration 611 / 3260) loss: 1.365989
# (Iteration 621 / 3260) loss: 1.452811
# (Iteration 631 / 3260) loss: 1.410342
# (Iteration 641 / 3260) loss: 1.463789
# (Iteration 651 / 3260) loss: 1.367960
# (Epoch 4 / 20) train acc: 0.516000; val_acc: 0.504000
# (Iteration 661 / 3260) loss: 1.528463
# (Iteration 671 / 3260) loss: 1.434865
# (Iteration 681 / 3260) loss: 1.562642
# (Iteration 691 / 3260) loss: 1.315781
# (Iteration 701 / 3260) loss: 1.304279
# (Iteration 711 / 3260) loss: 1.429453
# (Iteration 721 / 3260) loss: 1.344225
# (Iteration 731 / 3260) loss: 1.439994
# (Iteration 741 / 3260) loss: 1.423100
# (Iteration 751 / 3260) loss: 1.462784
# (Iteration 761 / 3260) loss: 1.310065
# (Iteration 771 / 3260) loss: 1.374691
# (Iteration 781 / 3260) loss: 1.458925
# (Iteration 791 / 3260) loss: 1.445569
# (Iteration 801 / 3260) loss: 1.346309
# (Iteration 811 / 3260) loss: 1.490880
# (Epoch 5 / 20) train acc: 0.542000; val_acc: 0.478000
# (Iteration 821 / 3260) loss: 1.347431
# (Iteration 831 / 3260) loss: 1.323456
# (Iteration 841 / 3260) loss: 1.291241
# (Iteration 851 / 3260) loss: 1.288531
# (Iteration 861 / 3260) loss: 1.310194
# (Iteration 871 / 3260) loss: 1.331148
# (Iteration 881 / 3260) loss: 1.252167
# (Iteration 891 / 3260) loss: 1.351447
# (Iteration 901 / 3260) loss: 1.319061
# (Iteration 911 / 3260) loss: 1.436090
# (Iteration 921 / 3260) loss: 1.393150
# (Iteration 931 / 3260) loss: 1.438791
# (Iteration 941 / 3260) loss: 1.281946
# (Iteration 951 / 3260) loss: 1.311605
# (Iteration 961 / 3260) loss: 1.423182
# (Iteration 971 / 3260) loss: 1.326181
# (Epoch 6 / 20) train acc: 0.546000; val_acc: 0.494000
# (Iteration 981 / 3260) loss: 1.215001
# (Iteration 991 / 3260) loss: 1.326605
# (Iteration 1001 / 3260) loss: 1.319412
# (Iteration 1011 / 3260) loss: 1.398452
# (Iteration 1021 / 3260) loss: 1.386414
# (Iteration 1031 / 3260) loss: 1.312859
# (Iteration 1041 / 3260) loss: 1.353398
# (Iteration 1051 / 3260) loss: 1.282134
# (Iteration 1061 / 3260) loss: 1.246381
# (Iteration 1071 / 3260) loss: 1.240590
# (Iteration 1081 / 3260) loss: 1.417508
# (Iteration 1091 / 3260) loss: 1.293656
# (Iteration 1101 / 3260) loss: 1.326459
# (Iteration 1111 / 3260) loss: 1.245825
# (Iteration 1121 / 3260) loss: 1.277334
# (Iteration 1131 / 3260) loss: 1.222357
# (Iteration 1141 / 3260) loss: 1.183012
# (Epoch 7 / 20) train acc: 0.573000; val_acc: 0.471000
# (Iteration 1151 / 3260) loss: 1.367388
# (Iteration 1161 / 3260) loss: 1.236427
# (Iteration 1171 / 3260) loss: 1.279477
# (Iteration 1181 / 3260) loss: 1.275077
# (Iteration 1191 / 3260) loss: 1.322438
# (Iteration 1201 / 3260) loss: 1.270630
# (Iteration 1211 / 3260) loss: 1.258117
# (Iteration 1221 / 3260) loss: 1.354225
# (Iteration 1231 / 3260) loss: 1.197389
# (Iteration 1241 / 3260) loss: 1.214767
# (Iteration 1251 / 3260) loss: 1.421023
# (Iteration 1261 / 3260) loss: 1.276410
# (Iteration 1271 / 3260) loss: 1.323986
# (Iteration 1281 / 3260) loss: 1.211254
# (Iteration 1291 / 3260) loss: 1.273417
# (Iteration 1301 / 3260) loss: 1.288752
# (Epoch 8 / 20) train acc: 0.539000; val_acc: 0.510000
# (Iteration 1311 / 3260) loss: 1.197377
# (Iteration 1321 / 3260) loss: 1.223965
# (Iteration 1331 / 3260) loss: 1.279183
# (Iteration 1341 / 3260) loss: 1.316371
# (Iteration 1351 / 3260) loss: 1.168756
# (Iteration 1361 / 3260) loss: 1.230249
# (Iteration 1371 / 3260) loss: 1.333384
# (Iteration 1381 / 3260) loss: 1.204178
# (Iteration 1391 / 3260) loss: 1.242681
# (Iteration 1401 / 3260) loss: 1.296512
# (Iteration 1411 / 3260) loss: 1.113452
# (Iteration 1421 / 3260) loss: 1.165405
# (Iteration 1431 / 3260) loss: 1.160067
# (Iteration 1441 / 3260) loss: 1.201366
# (Iteration 1451 / 3260) loss: 1.113270
# (Iteration 1461 / 3260) loss: 1.184137
# (Epoch 9 / 20) train acc: 0.544000; val_acc: 0.495000
# (Iteration 1471 / 3260) loss: 1.184138
# (Iteration 1481 / 3260) loss: 1.097780
# (Iteration 1491 / 3260) loss: 1.223109
# (Iteration 1501 / 3260) loss: 1.252276
# (Iteration 1511 / 3260) loss: 1.279549
# (Iteration 1521 / 3260) loss: 1.397080
# (Iteration 1531 / 3260) loss: 1.320319
# (Iteration 1541 / 3260) loss: 1.102020
# (Iteration 1551 / 3260) loss: 1.312662
# (Iteration 1561 / 3260) loss: 1.173791
# (Iteration 1571 / 3260) loss: 1.250548
# (Iteration 1581 / 3260) loss: 1.120214
# (Iteration 1591 / 3260) loss: 1.195750
# (Iteration 1601 / 3260) loss: 1.323150
# (Iteration 1611 / 3260) loss: 1.118109
# (Iteration 1621 / 3260) loss: 1.289499
# (Epoch 10 / 20) train acc: 0.587000; val_acc: 0.488000
# (Iteration 1631 / 3260) loss: 1.199268
# (Iteration 1641 / 3260) loss: 1.193396
# (Iteration 1651 / 3260) loss: 1.221731
# (Iteration 1661 / 3260) loss: 1.225402
# (Iteration 1671 / 3260) loss: 1.086689
# (Iteration 1681 / 3260) loss: 1.106442
# (Iteration 1691 / 3260) loss: 1.144327
# (Iteration 1701 / 3260) loss: 1.180049
# (Iteration 1711 / 3260) loss: 1.314194
# (Iteration 1721 / 3260) loss: 1.021988
# (Iteration 1731 / 3260) loss: 1.177540
# (Iteration 1741 / 3260) loss: 1.268126
# (Iteration 1751 / 3260) loss: 1.086216
# (Iteration 1761 / 3260) loss: 1.256671
# (Iteration 1771 / 3260) loss: 1.226782
# (Iteration 1781 / 3260) loss: 1.198879
# (Iteration 1791 / 3260) loss: 1.178512
# (Epoch 11 / 20) train acc: 0.585000; val_acc: 0.511000
# (Iteration 1801 / 3260) loss: 1.154753
# (Iteration 1811 / 3260) loss: 1.227081
# (Iteration 1821 / 3260) loss: 1.238498
# (Iteration 1831 / 3260) loss: 1.127722
# (Iteration 1841 / 3260) loss: 1.153822
# (Iteration 1851 / 3260) loss: 1.109864
# (Iteration 1861 / 3260) loss: 1.247274
# (Iteration 1871 / 3260) loss: 1.234896
# (Iteration 1881 / 3260) loss: 1.228143
# (Iteration 1891 / 3260) loss: 1.274803
# (Iteration 1901 / 3260) loss: 1.204276
# (Iteration 1911 / 3260) loss: 1.109787
# (Iteration 1921 / 3260) loss: 1.017101
# (Iteration 1931 / 3260) loss: 1.129410
# (Iteration 1941 / 3260) loss: 1.134670
# (Iteration 1951 / 3260) loss: 1.183566
# (Epoch 12 / 20) train acc: 0.589000; val_acc: 0.526000
# (Iteration 1961 / 3260) loss: 1.184960
# (Iteration 1971 / 3260) loss: 1.239269
# (Iteration 1981 / 3260) loss: 1.153635
# (Iteration 1991 / 3260) loss: 1.057604
# (Iteration 2001 / 3260) loss: 1.100702
# (Iteration 2011 / 3260) loss: 1.085005
# (Iteration 2021 / 3260) loss: 1.305003
# (Iteration 2031 / 3260) loss: 1.132360
# (Iteration 2041 / 3260) loss: 1.169632
# (Iteration 2051 / 3260) loss: 1.124672
# (Iteration 2061 / 3260) loss: 0.987703
# (Iteration 2071 / 3260) loss: 1.137560
# (Iteration 2081 / 3260) loss: 1.121238
# (Iteration 2091 / 3260) loss: 1.118855
# (Iteration 2101 / 3260) loss: 1.121932
# (Iteration 2111 / 3260) loss: 1.107985
# (Epoch 13 / 20) train acc: 0.600000; val_acc: 0.529000
# (Iteration 2121 / 3260) loss: 1.086201
# (Iteration 2131 / 3260) loss: 1.085444
# (Iteration 2141 / 3260) loss: 1.118288
# (Iteration 2151 / 3260) loss: 1.173860
# (Iteration 2161 / 3260) loss: 1.173412
# (Iteration 2171 / 3260) loss: 1.198365
# (Iteration 2181 / 3260) loss: 1.135461
# (Iteration 2191 / 3260) loss: 1.152891
# (Iteration 2201 / 3260) loss: 1.109808
# (Iteration 2211 / 3260) loss: 1.234703
# (Iteration 2221 / 3260) loss: 1.171579
# (Iteration 2231 / 3260) loss: 1.140565
# (Iteration 2241 / 3260) loss: 1.040910
# (Iteration 2251 / 3260) loss: 1.020332
# (Iteration 2261 / 3260) loss: 1.212267
# (Iteration 2271 / 3260) loss: 1.062818
# (Iteration 2281 / 3260) loss: 1.282591
# (Epoch 14 / 20) train acc: 0.618000; val_acc: 0.522000
# (Iteration 2291 / 3260) loss: 1.141211
# (Iteration 2301 / 3260) loss: 1.275169
# (Iteration 2311 / 3260) loss: 1.100778
# (Iteration 2321 / 3260) loss: 0.979597
# (Iteration 2331 / 3260) loss: 1.193554
# (Iteration 2341 / 3260) loss: 1.121367
# (Iteration 2351 / 3260) loss: 1.186868
# (Iteration 2361 / 3260) loss: 1.222675
# (Iteration 2371 / 3260) loss: 1.080284
# (Iteration 2381 / 3260) loss: 1.048286
# (Iteration 2391 / 3260) loss: 1.172903
# (Iteration 2401 / 3260) loss: 1.133899
# (Iteration 2411 / 3260) loss: 1.108314
# (Iteration 2421 / 3260) loss: 1.124599
# (Iteration 2431 / 3260) loss: 1.134738
# (Iteration 2441 / 3260) loss: 1.119470
# (Epoch 15 / 20) train acc: 0.626000; val_acc: 0.538000
# (Iteration 2451 / 3260) loss: 1.058822
# (Iteration 2461 / 3260) loss: 0.875334
# (Iteration 2471 / 3260) loss: 1.071827
# (Iteration 2481 / 3260) loss: 1.072677
# (Iteration 2491 / 3260) loss: 1.056293
# (Iteration 2501 / 3260) loss: 1.010358
# (Iteration 2511 / 3260) loss: 1.049833
# (Iteration 2521 / 3260) loss: 1.213931
# (Iteration 2531 / 3260) loss: 1.155863
# (Iteration 2541 / 3260) loss: 1.144832
# (Iteration 2551 / 3260) loss: 1.038908
# (Iteration 2561 / 3260) loss: 1.099828
# (Iteration 2571 / 3260) loss: 1.139666
# (Iteration 2581 / 3260) loss: 1.114187
# (Iteration 2591 / 3260) loss: 1.152096
# (Iteration 2601 / 3260) loss: 1.073487
# (Epoch 16 / 20) train acc: 0.627000; val_acc: 0.528000
# (Iteration 2611 / 3260) loss: 1.207311
# (Iteration 2621 / 3260) loss: 1.242418
# (Iteration 2631 / 3260) loss: 1.233235
# (Iteration 2641 / 3260) loss: 1.169613
# (Iteration 2651 / 3260) loss: 1.103461
# (Iteration 2661 / 3260) loss: 1.027459
# (Iteration 2671 / 3260) loss: 1.139632
# (Iteration 2681 / 3260) loss: 1.070137
# (Iteration 2691 / 3260) loss: 1.037841
# (Iteration 2701 / 3260) loss: 1.127766
# (Iteration 2711 / 3260) loss: 1.186953
# (Iteration 2721 / 3260) loss: 1.088371
# (Iteration 2731 / 3260) loss: 1.216595
# (Iteration 2741 / 3260) loss: 1.103278
# (Iteration 2751 / 3260) loss: 0.973934
# (Iteration 2761 / 3260) loss: 1.067868
# (Iteration 2771 / 3260) loss: 0.969314
# (Epoch 17 / 20) train acc: 0.604000; val_acc: 0.517000
# (Iteration 2781 / 3260) loss: 1.110026
# (Iteration 2791 / 3260) loss: 0.966278
# (Iteration 2801 / 3260) loss: 1.067748
# (Iteration 2811 / 3260) loss: 1.221895
# (Iteration 2821 / 3260) loss: 1.104961
# (Iteration 2831 / 3260) loss: 1.147146
# (Iteration 2841 / 3260) loss: 0.970185
# (Iteration 2851 / 3260) loss: 1.115184
# (Iteration 2861 / 3260) loss: 1.136503
# (Iteration 2871 / 3260) loss: 1.003776
# (Iteration 2881 / 3260) loss: 1.010421
# (Iteration 2891 / 3260) loss: 1.171292
# (Iteration 2901 / 3260) loss: 1.178913
# (Iteration 2911 / 3260) loss: 0.967216
# (Iteration 2921 / 3260) loss: 1.136793
# (Iteration 2931 / 3260) loss: 1.077473
# (Epoch 18 / 20) train acc: 0.605000; val_acc: 0.502000
# (Iteration 2941 / 3260) loss: 1.037147
# (Iteration 2951 / 3260) loss: 1.025840
# (Iteration 2961 / 3260) loss: 0.991555
# (Iteration 2971 / 3260) loss: 1.022700
# (Iteration 2981 / 3260) loss: 1.127518
# (Iteration 2991 / 3260) loss: 1.108018
# (Iteration 3001 / 3260) loss: 1.077425
# (Iteration 3011 / 3260) loss: 1.014611
# (Iteration 3021 / 3260) loss: 1.108871
# (Iteration 3031 / 3260) loss: 1.009095
# (Iteration 3041 / 3260) loss: 1.096468
# (Iteration 3051 / 3260) loss: 1.047160
# (Iteration 3061 / 3260) loss: 1.118451
# (Iteration 3071 / 3260) loss: 1.058864
# (Iteration 3081 / 3260) loss: 1.062729
# (Iteration 3091 / 3260) loss: 1.094160
# (Epoch 19 / 20) train acc: 0.655000; val_acc: 0.522000
# (Iteration 3101 / 3260) loss: 1.095488
# (Iteration 3111 / 3260) loss: 1.096155
# (Iteration 3121 / 3260) loss: 1.064936
# (Iteration 3131 / 3260) loss: 1.042192
# (Iteration 3141 / 3260) loss: 1.101273
# (Iteration 3151 / 3260) loss: 1.028814
# (Iteration 3161 / 3260) loss: 1.020709
# (Iteration 3171 / 3260) loss: 1.133882
# (Iteration 3181 / 3260) loss: 1.155893
# (Iteration 3191 / 3260) loss: 0.961919
# (Iteration 3201 / 3260) loss: 0.904795
# (Iteration 3211 / 3260) loss: 0.959166
# (Iteration 3221 / 3260) loss: 1.074572
# (Iteration 3231 / 3260) loss: 1.069903
# (Iteration 3241 / 3260) loss: 1.033499
# (Iteration 3251 / 3260) loss: 0.999652
# (Epoch 20 / 20) train acc: 0.660000; val_acc: 0.507000

# %%
best_model = model

# %% [markdown]
# # Test Your Model!
# Run your best model on the validation and test sets. You should achieve at least 50% accuracy on the validation set and the test set.

# %%
y_test_pred = np.argmax(best_model.loss(data['X_test']), axis=1)
y_val_pred = np.argmax(best_model.loss(data['X_val']), axis=1)
print('Validation set accuracy: ', (y_val_pred == data['y_val']).mean())
print('Test set accuracy: ', (y_test_pred == data['y_test']).mean())
# Out:
# Validation set accuracy:  0.538
# Test set accuracy:  0.506
